# %%
import xarray as xr
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import nc_time_axis
import cftime

# %%
data= pd.read_csv(r'C:\Users\mbirt\Downloads\Mayfield.csv')
xaxis = pd.DataFrame(data, columns=['Month'])
yaxis = pd.DataFrame(data, columns=['Height'])
time = [xaxis][yaxis]
time.plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_52888\1141929251.py in <module>
#       2 xaxis = pd.DataFrame(data, columns=['Month'])
#       3 yaxis = pd.DataFrame(data, columns=['Height'])
# ----> 4 time = [xaxis][yaxis]
#       5 time.plot()
#
# TypeError: list indices must be integers or slices, not DataFrame

# %%
var = pd.read_csv(r'C:\Users\mbirt\Downloads\Mayfield.csv')
x = list(var['Month'])
y = list(var['Height'])
plt.figure(figsize=(10,10))
#makes scatter plot with stars as the points for each data point
#plt.scatter(x,y,marker=".",s=100,edgecolors="black",c="yellow")
# makes scatter plot with regular dots at each point, but lines not connected
#plt.scatter(x,y)
#plt.plot(x,y) just plots as you want with lines connected etc.
plt.plot(x,y)
ax = plt.gca()
#sets limits on x and y values for the graph to find the right window for analysis etc. 
ax.set_xlim([2000,2023])
ax.set_ylim([6000,8000])
plt.show()
