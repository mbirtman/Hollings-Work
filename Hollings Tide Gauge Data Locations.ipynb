# %%
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
import cartopy.feature as cfeature

#ax = plt.axes(projection=ccrs.PlateCarree())
#ax.coastlines()

#plt.show()
import pandas as pd

# %%
ax = plt.axes(projection=ccrs.Mollweide())
ax.stock_img()
data = pd.read_csv(r"C:\Users\mbirt\Downloads\New Draft Tide Gauge Data.csv")
lat = pd.DataFrame(data, columns=['lat'])
lon = pd.DataFrame(data, columns=['lon'])
ax.set_global()
plt.scatter(x=lon, y=lat, color="red", s=4, alpha=1, transform=ccrs.PlateCarree())
plt.show()
